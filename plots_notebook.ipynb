# %%
import Pkg
Pkg.add("Plots")
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\alexa\.julia\environments\v1.7\Project.toml`
#   No Changes to `C:\Users\alexa\.julia\environments\v1.7\Manifest.toml`

# %%
using Plots
x = 1:10; y = rand(10); # These are the plotting data
plot(x, y)
